# %% [markdown]
# # LCP mod. B – Exercise n. 1: Gradient Descent & DNNs
#
# ### List of students
#
# ```
# Davide Bacilieri 2089214
# Lorenzo Barbiero 2082142
# Guglielmo Bordin 2088622
# Alessio Pitteri  2090594
# ```

# %% [markdown]
# ## Step 0. Importing Stuff

# %%
import numpy as np
import numpy.random as npr

import keras as kr
from keras.models import Sequential
from keras.layers import Dense, Dropout
import keras.optimizers as opt

from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('image', cmap='copper')
plt.rcParams['font.size'] = 15

import seaborn as sns

# %run nonlinear_function.py

# set tensorflow seed for reproducibility
np.random.seed(12345)
import tensorflow.random as tfr
tfr.set_seed(12345)
# Out:
# 2023-03-07 23:12:00.877397: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:04.325888: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:04.325967: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:04.325974: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Step 1. Loading and Processing the Data
# We’ll be doing cross validation later, so we’re not splitting the dataset in training and test sets until after we’ve chosen the best hyperparameters.

# %%
TYPE = 1
x = np.loadtxt(filename('data', TYPE), delimiter=' ')
y = np.loadtxt(filename('labels', TYPE), delimiter=' ')
N = len(x)     # number of samples
L = len(x[0])  # dimension of each sample

# rescaling of the data (as done in class)
x /= 50

print(f'Number of samples: {N}')
# Out:
# Number of samples: 4000

# %% [markdown]
# ## Step 2. Definition of the Model
# Here we build the architecture: we’ve chosen to build a network with four hidden 20-neuron layers followed by a single dropout layer. The output layer is a single neuron with sigmoid activation, to map the output to the range $(0, 1)$.
#
# The module construction function requires three inputs: the dropout percentage for the second-to-last layer, the optimizer name, and the learning rate value. We’ll optimize all of these parameters through a grid search later on.

# %%
# for some reason, GridSearchCV needs a default optimizer value here
def compile_model(dropout_rate, learning_rate, optimizer=opt.Adam):
    # build DNN layer by layer
    model = Sequential()
    # input layer
    model.add(Dense(L, input_shape=(L, ), activation='relu'))
    # 4 hidden layers
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='relu'))
    # dropout layer
    model.add(Dropout(dropout_rate))
    # last single-neuron layer
    model.add(Dense(1, activation='sigmoid'))

    # compile the model
    model.compile(loss=kr.losses.binary_crossentropy,
                  optimizer=optimizer(learning_rate=learning_rate),
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Step 3. Grid Search Optimization
# Here we’ll perform a grid search optimization with cross-validation, thanks to the function `GridSearchCV` from `scikit-learn`. As anticipated, we’ll search for the best combination of the optimization algorithm, its learning rate and the dropout rate for the second-to-last layer.

# %%
optalg_list = [opt.Adam, opt.RMSprop, opt.Nadam, opt.Adamax]
lrate_list = [10**i for i in range(-2, -5, -1)]
dout_list = [10**i for i in range(-1, -5, -1)]

# define parameter dictionary
param_grid = dict(optimizer=optalg_list,
                  learning_rate=lrate_list,
                  dropout_rate=dout_list)

# call Keras scikit wrapper
model_gridsearch = KerasClassifier(model=compile_model,
                                   optimizer=opt.Adam,
                                   dropout_rate=0.01,
                                   learning_rate=0.01,
                                   epochs=400,
                                   batch_size=50,
                                   verbose=0)
# call scikit grid search module
# adjust n_jobs to number of cores on your machine
grid = GridSearchCV(estimator=model_gridsearch,
                    param_grid=param_grid,
                    n_jobs=8, # 2 for colab
                    cv=4)

# %%
grid_result = grid.fit(x, y)

# summarize results
print(f'Best:\n {grid_result.best_score_}')
print(f'using:\n {grid_result.best_params_}\n')

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, par in zip(means, stds, params):
    print(f'Score {mean} ± {stdev} with: {par}')
# Out:
# 2023-03-07 23:12:07.900554: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:07.984513: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:07.988837: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:07.989638: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:08.002917: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:08.037021: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:08.055399: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:08.134943: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:09.693254: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:09.693942: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:09.693973: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:09.983655: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:09.984051: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:09.984073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.013970: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.014293: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.014314: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.041182: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.041749: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.041946: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.083046: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.083332: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.083403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.089418: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.089711: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.089776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.104886: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.105286: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.105393: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:10.266053: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.266595: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:12:10.266756: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:12:13.458201: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.458252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.459907: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.463537: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.463637: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.464726: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.473556: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.473617: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.474039: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.477773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.477825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.478464: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.478518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.478930: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.478932: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.552213: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.552258: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.552606: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.568449: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.568495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.569030: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:12:13.612974: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:12:13.613584: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:12:13.614328: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/davide/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 2023-03-07 23:44:10.935642: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:44:13.423147: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:44:13.423562: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:44:13.423880: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:44:16.529930: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:44:16.530531: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:44:16.531625: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:45:51.683781: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:45:54.137256: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:45:54.137466: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:45:54.137490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:45:57.186390: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:45:57.186454: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:45:57.186952: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:46:39.421244: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:46:41.920351: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:46:41.920778: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:46:41.920805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:46:43.844722: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:46:45.002896: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:46:45.003512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:46:45.004220: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:46:46.386228: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:46:46.386977: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-07 23:46:46.387244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-07 23:46:49.000566: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:46:49.000629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:46:49.001100: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 23:49:23.448933: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-07 23:49:23.448983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (davide-PC): /proc/driver/nvidia/version does not exist
# 2023-03-07 23:49:23.449656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Best:
#  0.983
# using:
#  {'dropout_rate': 0.001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
#
# Score 0.952 ± 0.03655817282086181 with: {'dropout_rate': 0.1, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.8985 ± 0.042169301630451496 with: {'dropout_rate': 0.1, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.8915000000000001 ± 0.08113722943261002 with: {'dropout_rate': 0.1, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.8985000000000001 ± 0.04829337428674869 with: {'dropout_rate': 0.1, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.92325 ± 0.0369145973836909 with: {'dropout_rate': 0.1, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.9497499999999999 ± 0.028252212302756024 with: {'dropout_rate': 0.1, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.8995 ± 0.02973634140239854 with: {'dropout_rate': 0.1, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.93275 ± 0.05328402668717895 with: {'dropout_rate': 0.1, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.8747499999999999 ± 0.04323410112399701 with: {'dropout_rate': 0.1, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.86525 ± 0.029235038908816274 with: {'dropout_rate': 0.1, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.84825 ± 0.03872579889427718 with: {'dropout_rate': 0.1, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.8867499999999999 ± 0.07563192117089185 with: {'dropout_rate': 0.1, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.8927499999999999 ± 0.043083494519363205 with: {'dropout_rate': 0.01, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.896 ± 0.04194639436232868 with: {'dropout_rate': 0.01, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9437499999999999 ± 0.045620033976313513 with: {'dropout_rate': 0.01, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.981 ± 0.006964194138592066 with: {'dropout_rate': 0.01, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.96175 ± 0.0319951168149141 with: {'dropout_rate': 0.01, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.944 ± 0.04244997055358224 with: {'dropout_rate': 0.01, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9052499999999999 ± 0.04664962486451525 with: {'dropout_rate': 0.01, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.92825 ± 0.05402950582783447 with: {'dropout_rate': 0.01, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.87675 ± 0.034127518222103435 with: {'dropout_rate': 0.01, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.88675 ± 0.017426631917843462 with: {'dropout_rate': 0.01, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.873 ± 0.07004284403134982 with: {'dropout_rate': 0.01, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.9015 ± 0.03464462440264 with: {'dropout_rate': 0.01, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.9277500000000001 ± 0.05391834103531005 with: {'dropout_rate': 0.001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.9612499999999999 ± 0.029192250684042825 with: {'dropout_rate': 0.001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9822500000000001 ± 0.010497023387608518 with: {'dropout_rate': 0.001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.92725 ± 0.05017158060097368 with: {'dropout_rate': 0.001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.964 ± 0.036462309307009055 with: {'dropout_rate': 0.001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.983 ± 0.00777817459305203 with: {'dropout_rate': 0.001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9309999999999999 ± 0.09757561170702442 with: {'dropout_rate': 0.001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.9165 ± 0.04755260245244206 with: {'dropout_rate': 0.001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.8895 ± 0.042204857540335323 with: {'dropout_rate': 0.001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.86375 ± 0.02772521415607103 with: {'dropout_rate': 0.001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.82525 ± 0.05758200673821642 with: {'dropout_rate': 0.001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.904 ± 0.03238054971738434 with: {'dropout_rate': 0.001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.9545 ± 0.04825712382643623 with: {'dropout_rate': 0.0001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.9365 ± 0.05185797913532689 with: {'dropout_rate': 0.0001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9315 ± 0.08413233623286587 with: {'dropout_rate': 0.0001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.9505 ± 0.058696252009817464 with: {'dropout_rate': 0.0001, 'learning_rate': 0.01, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.9382499999999999 ± 0.04373999885688154 with: {'dropout_rate': 0.0001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.9192499999999999 ± 0.04950441899467157 with: {'dropout_rate': 0.0001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.9515 ± 0.04194341426255139 with: {'dropout_rate': 0.0001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.9524999999999999 ± 0.0558949908310217 with: {'dropout_rate': 0.0001, 'learning_rate': 0.001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}
# Score 0.9037499999999999 ± 0.046724592026041276 with: {'dropout_rate': 0.0001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>}
# Score 0.89125 ± 0.031155858197135233 with: {'dropout_rate': 0.0001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>}
# Score 0.8855 ± 0.02339337513057919 with: {'dropout_rate': 0.0001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.nadam.Nadam'>}
# Score 0.869 ± 0.05510444628158418 with: {'dropout_rate': 0.0001, 'learning_rate': 0.0001, 'optimizer': <class 'keras.optimizers.optimizer_v2.adamax.Adamax'>}

# %% [markdown]
# ## Step 4. Visualization of the Grid Search Results
# Here we’ll plot the mean cross-validation score of the various combination of parameters analysed in the grid search.

# %%
glob = [(m, p) for m, p in zip(means, params)]
# sort by optimizer name, alphabetically
glob = sorted(glob, key=lambda i: str(i[1]['optimizer']))

n_lrate = len(lrate_list)
n_dout = len(dout_list)
opt_chunk = n_lrate * n_dout

# human readable names for the algorithms
opt_names = ['Adam', 'Adamax', 'Nadam', 'RMSprop']

fig, ax = plt.subplots(ncols=len(optalg_list), nrows=1, figsize=(16, 7))
for i_op in range(len(optalg_list)):
    # all data from the i_op-th optimizer
    op = glob[i_op * opt_chunk:(i_op + 1) * opt_chunk]
    # dataframe with different learning rates in the columns
    # and different dropouts in the rows
    d = [[op[i + n_lrate * j][0]
          for i in range(len(lrate_list))]
         for j in range(len(dout_list))]
    df = pd.DataFrame(d, index=dout_list, columns=lrate_list)
    sns.heatmap(df, annot=True, cmap='Blues',
               # common colorbar displayed in the last plot
               ax=ax[i_op], vmin=0.8, vmax=1, cbar=i_op==3)
    # set optimizer name as title
    ax[i_op].set_title(opt_names[i_op])

# common labels
fig.supxlabel('Learning rate')
fig.supylabel('Dropout value')
fig.tight_layout()
#0.98125 ± 0.00432290411644765  for Nadam
#0.9844999999999999 ± 0.0038405728739343073 for Adam

# %% [markdown]
# ## Step 5. Increasing and Reducing the Amount of Data
# Here we’ll investigate what happens when we change the amount of input data: we’ll start from the previous dataset, and we’ll train our best model on different percentanges of it.
#
# First, we’ll set the hyper-parameters to the best values that we found with the grid search.

# %%
best_opt = opt.Nadam # TODO after run
best_lrate = 0.001 # TODO after run
best_dout = 0.1 # TODO after run

# %% [markdown]
# We’ll fix the validation set to 20% of the total training data. Then, we’ll gradually decrease the training set size from the starting 80% and plot the results each time. We’ll display a plot for the training and validation accuracy through the epochs, a similar plot for the cross-entropy loss, and a scatter plot with the color-coded prediction of the model.

# %%
# first training/validation partition
(x, y) = shuffle(x, y, random_state=12345)
perc_train = 0.8
N_train = int(perc_train * N)

(x_train, y_train) = (x[0:N_train], y[0:N_train])
(x_valid, y_valid) = (x[N_train:], y[N_train:])
# data was already rescaled

# plot of the first sets
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].scatter(x_train[:, 0], x_train[:, 1], c=y_train)
ax[0].set_title('Training set (80%)')
ax[1].scatter(x_valid[:, 0], x_valid[:, 1], c=y_valid)
ax[1].set_title('Validation set (20%)')
# Out:
# Text(0.5, 1.0, 'Validation set (20%)')

# %%
fig, AX = plt.subplots(20, 3, figsize=(16, 100))

# fit parameters
nepochs = 400
bsize = 50

# lists to save the losses and accuracies for later plotting
losses = []
accs = []

row = 0
for n in range(100, 0, -5):
    print(n, '% of 1st training set')
    # first shuffle
    (x_train, y_train) = shuffle(x_train, y_train, random_state=12345)
    # then cut
    perc_train = int(N_train * n / 100)
    (x_train, y_train) = (x_train[0:perc_train], y_train[0:perc_train])

    # function to build the model defined before
    model = compile_model(best_dout, best_lrate, best_opt)

    fit = model.fit(x_train, y_train,
                    epochs=nepochs, batch_size=bsize,
                    validation_data=(x_valid, y_valid),
                    verbose=0)

    results = model.evaluate(x_valid, y_valid)
    predictions = model.predict(x_valid)

    loss, acc = results
    losses.append(loss)
    accs.append(acc)

    # accuracy plot
    ax = AX[row][0]
    ax.plot(fit.history['accuracy'], label='Train', c='b')
    ax.plot(fit.history['val_accuracy'], label='Valid.', c='r')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')
    ax.legend()

    # loss plot
    ax = AX[row][1]
    ax.plot(fit.history['loss'], label='Train', c='b')
    ax.plot(fit.history['val_loss'], label='Valid.', c='r')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()

    # prediction plot
    ax = AX[row][2]
    ax.scatter(x_valid[:, 0], x_valid[:, 1], c=predictions)
    ax.set_title(f'{n}% of 1st training set')
    row += 1
# Out:
# 100 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9900
# 25/25 [==============================] - 0s 1ms/step
# 95 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9900
# 25/25 [==============================] - 0s 1ms/step
# 90 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0401 - accuracy: 0.9875
# 25/25 [==============================] - 0s 2ms/step
# 85 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9900
# 25/25 [==============================] - 0s 2ms/step
# 80 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.8700
# 25/25 [==============================] - 0s 898us/step
# 75 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9812
# 25/25 [==============================] - 0s 902us/step
# 70 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9762
# 25/25 [==============================] - 0s 2ms/step
# 65 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.9625
# 25/25 [==============================] - 0s 908us/step
# 60 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1823 - accuracy: 0.9050
# 25/25 [==============================] - 0s 899us/step
# 55 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2806 - accuracy: 0.8662
# 25/25 [==============================] - 0s 2ms/step
# 50 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.8913
# 25/25 [==============================] - 0s 2ms/step
# 45 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.8675
# 25/25 [==============================] - 0s 1ms/step
# 40 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9725
# 25/25 [==============================] - 0s 2ms/step
# 35 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2800 - accuracy: 0.8675
# 25/25 [==============================] - 0s 1ms/step
# 30 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9137
# 25/25 [==============================] - 0s 848us/step
# 25 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2083 - accuracy: 0.8950
# 25/25 [==============================] - 0s 763us/step
# 20 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3101 - accuracy: 0.8400
# 25/25 [==============================] - 0s 846us/step
# 15 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.9262
# 25/25 [==============================] - 0s 2ms/step
# 10 % of 1st training set
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.9125
# 25/25 [==============================] - 0s 895us/step
# 5 % of 1st training set
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.7538
# 25/25 [==============================] - 0s 2ms/step

# %% [markdown]
# Here’s a plot of the accuracies and the losses as a function of the training set size (i.e., percentage of the first training set size).

# %%
percentage = np.arange(100, 0, -5)
plt.scatter(percentage, losses, label='Loss')
plt.scatter(percentage, accs, label='Accuracy')
plt.xlabel('% of the 1st training set')
plt.legend()

# %% [markdown]
# ## Step 6. Data Augmentation
# In this section we’ll implement an *augmentation* of the training data, i.e. we’ll generate new samples by applying random transformations to the starting data. Of course, this is not at all the same as getting actual new data, so we’re investigating whether this fictitious enlargement of the training set does any good to the training.
#
# First, we’ll report the reasoning behind our choice of the data augmentation method. To illustrate the available options and their potential issues (especially in the boundaries of the training space, which were given special attention), we’ll create a dummy dataset. Then, we’ll go over the three options we came up with.

# %%
n = 100
data = 2 * npr.rand(2, n) - 1
plt.scatter(data[1], data[0])
plt.show()

# %% [markdown]
# #### First method: simply adding random noise
# This is easy to implement, but the training region ends up being bigger than the validation (and original data) region.

# %%
alpha = 0.2
data_aug = data + alpha * (2 * npr.rand(2, n) - 1)
plt.scatter(data[1], data[0], label='Starting data')
plt.scatter(data_aug[1], data_aug[0], label='Augmented data')
plt.legend()
plt.show()

# %% [markdown]
# #### Second method: adding random noise and truncate to the original boundaries
# This is also easy to implement, it’s the same as the first with the addition of a mask. However, the augmented data density will be lower in the boundary region, due to the possible rejection of newly generated points.

# %%
data_aug = data + alpha * (2 * npr.rand(2, n) - 1)

# boolean mask to remove points outside of [-1, 1] in x and y coordinates
mask = (np.abs(data_aug[0]) <= 1) & (np.abs(data_aug[1]) <= 1)
data_aug = data_aug[:, mask]

plt.scatter(data[1], data[0], label='Starting data')
plt.scatter(data_aug[1], data_aug[0], label='Augmented data')
plt.legend()
plt.show()

# %% [markdown]
# #### Third method: adding random noise and treat the boundaries as reflective walls
# For example, if an `x` is generated as `1.03` it will be transformed to `x = 0.97`, as per a reflection. This is slightly more difficult to implement, but it should solve both of the previous issues, since samples outside the boundary are put back in the domain.

# %%
data_aug = data + alpha * (2 * npr.rand(2, n) - 1)

# reflect points outside of [-1, 1] in x and y coordinates
data_aug[0] = np.where(np.abs(data_aug[0]) <= 1,
                       data_aug[0],
                       np.sign(data_aug[0]) * (2 - np.abs(data_aug[0])))
data_aug[1] = np.where(np.abs(data_aug[1]) <= 1,
                       data_aug[1],
                       np.sign(data_aug[1]) * (2 - np.abs(data_aug[1])))

plt.scatter(data[1], data[0], label='Starting data')
plt.scatter(data_aug[1], data_aug[0], label='Augmented data')
plt.legend()
plt.show()

# %% [markdown]
# So, let’s choose the third method and proceed with the augmentation of the actual dataset.

# %%
perc_train = 0.8
N_train = int(perc_train * N)

(x, y) = shuffle(x, y, random_state=12345)
(x_train, y_train) = (x[0:N_train], y[0:N_train])
(x_valid, y_valid) = (x[N_train:], y[N_train:])
print(f'Number of training samples: {N_train}')
print(f'Number of validation samples: {N - N_train}')
# Out:
# Number of training samples: 3200
# Number of validation samples: 800

# %%
# number of copies of the data to augment
N_aug = 2
# a reasonable choice of the alpha parameter (after some tests)
alpha = 0.03

x_aug = x_train
y_aug = y_train
for i in range(0, N_aug):
    # generate
    data_aug_x = x_train + alpha * (2 * npr.rand(N_train, 2) - 1)
    # reflect across the boundaries
    data_aug_x[:, 0] = np.where(np.abs(data_aug_x[:, 0]) <= 1,
                                data_aug_x[:, 0],
                                np.sign(data_aug_x[:, 0])
                                        * (2 - np.abs(data_aug_x[:, 0])))
    data_aug_x[:, 1] = np.where(np.abs(data_aug_x[:, 1]) <= 1,
                                data_aug_x[:, 1],
                                np.sign(data_aug_x[:, 1])
                                        * (2 - np.abs(data_aug_x[:, 1])))
    # join to the original data
    x_aug = np.concatenate((x_aug, data_aug_x), axis=0)
    y_aug = np.concatenate((y_aug, y_train))

plt.figure(figsize=(6, 6))
plt.scatter(x_aug[:, 0], x_aug[:, 1], c=y_aug)
plt.show()

# %% [markdown]
# Then, we train the model with the best architecture…

# %%
model = compile_model(dropout_rate=best_dout,
                      learning_rate=best_lrate,
                      optimizer=best_opt)

fit = model.fit(x_aug, y_aug,
                epochs=1000, batch_size=bsize,
                validation_data=(x_valid, y_valid),
                verbose=0)

# %% [markdown]
# … and visualize the results.

# %%
fig, AX = plt.subplots(1, 2, figsize=(15, 6))

ax = AX[0]
ax.plot(fit.history['accuracy'], label='Train', c='b')
ax.plot(fit.history['val_accuracy'], label='Valid.', c='r')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend()

ax = AX[1]
ax.plot(fit.history['loss'], label='Train', c='b')
ax.plot(fit.history['val_loss'], label='Valid.', c='r')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()

plt.show()

# %% [markdown]
# Now, we’ll plot the data with the prediction, highlighting the region where the predicted label is bigger than $1/2$.

# %%
dX = 2
X1 = np.arange(-50, 50 + dX, dX)
LG = len(X1)

grid = np.zeros((LG * LG, 2))
k = 0

for i in range(LG):
    for j in range(LG):
        grid[k, :] = (X1[j], X1[i])
        k += 1
grid_r = grid / 50

pred = model.predict(grid_r)

def boundaries():  
    x1 = -25
    y1 = -35
    c = '#AAAAFF'
    a = 0.5
    lw = 5
    ax.plot((50, -20), (-20, 50), c=c, alpha=a, lw=lw)
    ax.plot((50, 0), (0, 50), c=c, alpha=a, lw=lw)
    ax.plot((x1, 50), (y1, y1), c=c, alpha=a, lw=lw)
    ax.plot((x1, x1), (y1, 50),c=c, alpha=a, lw=lw)

fig, AX = plt.subplots(1, 3, figsize =(16, 5))

ax = AX[0]
ax.scatter(50*x[:, 0], 50*x[:, 1], c=y)
boundaries()
ax.set_title('Data')

ax = AX[1]
ax.scatter(grid[:, 0], grid[:, 1], c=pred)
boundaries()
ax.set_title('Prediction $\\hat y$')

ax = AX[2]
W1 = np.where(pred > 0.5)[0] 
ax.scatter(grid[:, 0], grid[:, 1], c='#000000')
ax.scatter(grid[W1, 0], grid[W1, 1], c='#ffc77f')
boundaries()
ax.set_title('Where $\\hat y > 1/2$')
plt.show()
# Out:
# 82/82 [==============================] - 0s 1ms/step

# %% [markdown]
# Testing with various amounts of noise ($0.01 < \alpha < 0.05$) shows that, despite satisfying performances on the validation set, the training on augmented data can never be as stable, reliable and efficient as the training on just real data. This is reasonable, since random noise is, by definition, not learnable; so, at best we can achieve the same result as before.
